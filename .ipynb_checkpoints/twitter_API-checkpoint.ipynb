# %%
import tweepy
import config
import numpy as np

# %%
twitter_auth = tweepy.OAuthHandler(config.consumer_key, config.consumer_key_secret)
api = tweepy.API(twitter_auth)

tweets = api.search("data", lang='en', count=200) # Search term goes here

print(tweets)
# Out:
# [Status(_api=<tweepy.api.API object at 0x000001479D87AC88>, _json={'created_at': 'Mon Jul 13 23:44:53 +0000 2020', 'id': 1282823343146594306, 'id_str': '1282823343146594306', 'text': "@Droolianna the Gov't is gathering data on every one of us rn. However, the NSA only has like 10k employees. No one… https://t.co/PorH3W5H3M", 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Droolianna', 'name': 'Juju 𖤐', 'id': 604794975, 'id_str': '604794975', 'indices': [0, 11]}], 'urls': [{'url': 'https://t.co/PorH3W5H3M', 'expanded_url': 'https://twitter.com/i/web/status/1282823343146594306', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': 1282741081025675267, 'in_reply_to_status_id_str': '1282741081025675267', 'in_reply_to_user_id': 604794975, 'in_reply_to_user_id_str': '604794975', 'in_reply_to_screen_name': 'Droolianna', 'user': {'id': 1310114539, 'id_str': '1310114539', 'name': 'DJ Menace', 'screen_name': 'Sakrelige', 'location': '', 'description': 'singer/songwriter/producer/tech', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 23, 'friends_count': 83, 'listed_count': 1, 'created_at': 'Thu Mar 28 10:19:53 +0000 2013', 'favourites_count': 80, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 282, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/560679651597484032/KBJAOkZP_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/560679651597484032/KBJAOkZP_normal.jpeg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 7, 13, 23, 44, 53), id=1282823343146594306, id_str='1282823343146594306', text="@Droolianna the Gov't is gathering data on every one of us rn. However, the NSA only has like 10k employees. No one… https://t.co/PorH3W5H3M", truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Droolianna', 'name': 'Juju 𖤐', 'id': 604794975, 'id_str': '604794975', 'indices': [0, 11]}], 'urls': [{'url': 'https://t.co/PorH3W5H3M', 'expanded_url': 'https://twitter.com/i/web/status/1282823343146594306', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=1282741081025675267, in_reply_to_status_id_str='1282741081025675267', in_reply_to_user_id=604794975, in_reply_to_user_id_str='604794975', in_reply_to_screen_name='Droolianna', author=User(_api=<tweepy.api.API object at 0x000001479D87AC88>, _json={'id': 1310114539, 'id_str': '1310114539', 'name': 'DJ Menace', 'screen_name': 'Sakrelige', 'location': '', 'description': 'singer/songwriter/producer/tech', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 23, 'friends_count': 83, 'listed_count': 1, 'cre ...

# %%
import re
import pandas as pd


df = pd.DataFrame(columns=('tweet_text', 'user_location', 
                           'user_followers_count', 'user_friends_count',
                           'user_account_age', 'user_verified',
                           'user_favourites_count', 'user_tweets',
                           'tweet_retweeted', 'tweet_retweet_count', 'tweet_favorite_count'))

# Remove duplicates
df.sort_values("tweet_text", inplace = True) 
df.drop_duplicates(subset ="tweet_text", keep = False, inplace = True) 

for tweet in tweets:

    df = df.append({'user_id': tweet.user.id_str,
                    'user': tweet.user.screen_name,
                    'tweet_text': re.sub(r'http\S+', '', tweet.text), #Remove links
                    'tweet_date': tweet.created_at,
                    'user_location': tweet.user.location,
                    'user_followers_count': tweet.user.followers_count, 
                    'user_friends_count': tweet.user.friends_count,
                    'user_account_age': tweet.user.created_at, 
                    'user_verified': tweet.user.verified,
                    'user_favourites_count': tweet.user.favourites_count,
                    'user_tweets': tweet.user.statuses_count,
                    'tweet_retweeted': tweet.retweeted,
                    'tweet_retweet_count': tweet.retweet_count,
                    'tweet_favorite_count': tweet.favorite_count},
                   ignore_index=True)

df.head()
# Out:
#                                           tweet_text  user_location  \
# 0  @Droolianna the Gov't is gathering data on eve...
# 1  RT @CNN: Florida reported its highest number o...        She/Her
# 2       Breached Data Indexer ‘Data Viper’ Hacked -          Boston
# 3  RT @dbongino: Liberalism is a cancer. Liberals...  United States
# 4  RT @Melfox_14: Anyone know of good places to l...      Minnesota
#
#   user_followers_count user_friends_count    user_account_age user_verified  \
# 0                   23                 83 2013-03-28 10:19:53         False
# 1                  315                 81 2016-08-01 16:21:43         False
# 2                   26                 62 2013-02-07 15:59:01         False
# 3                 1624               1478 2011-10-12 15:07:08         False
# 4                 1898                568 2012-10-21 01:04:58         False
#
#   user_favourites_count user_tweets tweet_retweeted tweet_retweet_count  \
# 0                    80         282           False                   0
# 1                101128       40364           False                 664
# 2                     0        1609           False                   0
# 3                126024       34852           False                4455
# 4                  1629        3083           False                   1
#
#   tweet_favorite_count          tweet_date             user  \
# 0                    0 2020-07-13 23:44:53        Sakrelige
# 1                    0 2020-07-13 23:44:53         Legpussy
# 2                    0 2020-07-13 23:44:51        NESafetyP
# 3                    0 2020-07-13 23:44:51  thoughtful1more
# 4                    0 2020-07-13 23:44:51       kitsunekla
#
#               user_id
# 0          1310114539
# 1  760148514206875648
# 2          1157511132
# 3           389511785
# 4           894357715

# %%
df=df[['user_id', 'tweet_date', 'user', 'tweet_text']]
df.head()
# Out:
#               user_id          tweet_date             user  \
# 0          1310114539 2020-07-13 23:44:53        Sakrelige
# 1  760148514206875648 2020-07-13 23:44:53         Legpussy
# 2          1157511132 2020-07-13 23:44:51        NESafetyP
# 3           389511785 2020-07-13 23:44:51  thoughtful1more
# 4           894357715 2020-07-13 23:44:51       kitsunekla
#
#                                           tweet_text
# 0  @Droolianna the Gov't is gathering data on eve...
# 1  RT @CNN: Florida reported its highest number o...
# 2       Breached Data Indexer ‘Data Viper’ Hacked -
# 3  RT @dbongino: Liberalism is a cancer. Liberals...
# 4  RT @Melfox_14: Anyone know of good places to l...

# %%
#Remove handles

def remove_pattern(input_txt, pattern):
  r = re.findall(pattern, input_txt)
  for i in r:
    input_txt = re.sub(i, '', input_txt)

  return input_txt

df['tidy_tweet'] = np.vectorize(remove_pattern)(df['tweet_text'], "@[\w]*")

df.head()
# Out:
#               user_id          tweet_date             user  \
# 0          1310114539 2020-07-13 23:44:53        Sakrelige
# 1  760148514206875648 2020-07-13 23:44:53         Legpussy
# 2          1157511132 2020-07-13 23:44:51        NESafetyP
# 3           389511785 2020-07-13 23:44:51  thoughtful1more
# 4           894357715 2020-07-13 23:44:51       kitsunekla
#
#                                           tweet_text  \
# 0  @Droolianna the Gov't is gathering data on eve...
# 1  RT @CNN: Florida reported its highest number o...
# 2       Breached Data Indexer ‘Data Viper’ Hacked -
# 3  RT @dbongino: Liberalism is a cancer. Liberals...
# 4  RT @Melfox_14: Anyone know of good places to l...
#
#                                           tidy_tweet
# 0   the Gov't is gathering data on every one of u...
# 1  RT : Florida reported its highest number of ne...
# 2       Breached Data Indexer ‘Data Viper’ Hacked -
# 3  RT : Liberalism is a cancer. Liberals hate fre...
# 4  RT : Anyone know of good places to look for re...

# %%
#Remove special characters, number, and punctuation

df['tidy_tweet'] = df['tidy_tweet'].str.replace("[^a-zA-Z#]", " " )
df.head()
# Out:
#               user_id          tweet_date             user  \
# 0          1310114539 2020-07-13 23:44:53        Sakrelige
# 1  760148514206875648 2020-07-13 23:44:53         Legpussy
# 2          1157511132 2020-07-13 23:44:51        NESafetyP
# 3           389511785 2020-07-13 23:44:51  thoughtful1more
# 4           894357715 2020-07-13 23:44:51       kitsunekla
#
#                                           tweet_text  \
# 0  @Droolianna the Gov't is gathering data on eve...
# 1  RT @CNN: Florida reported its highest number o...
# 2       Breached Data Indexer ‘Data Viper’ Hacked -
# 3  RT @dbongino: Liberalism is a cancer. Liberals...
# 4  RT @Melfox_14: Anyone know of good places to l...
#
#                                           tidy_tweet
# 0   the Gov t is gathering data on every one of u...
# 1  RT   Florida reported its highest number of ne...
# 2       Breached Data Indexer  Data Viper  Hacked
# 3  RT   Liberalism is a cancer  Liberals hate fre...
# 4  RT   Anyone know of good places to look for re...

# %%
#Remove short words

df['tidy_tweet'] = df['tidy_tweet'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>3]))
df.head()
# Out:
#               user_id          tweet_date             user  \
# 0          1310114539 2020-07-13 23:44:53        Sakrelige
# 1  760148514206875648 2020-07-13 23:44:53         Legpussy
# 2          1157511132 2020-07-13 23:44:51        NESafetyP
# 3           389511785 2020-07-13 23:44:51  thoughtful1more
# 4           894357715 2020-07-13 23:44:51       kitsunekla
#
#                                           tweet_text  \
# 0  @Droolianna the Gov't is gathering data on eve...
# 1  RT @CNN: Florida reported its highest number o...
# 2       Breached Data Indexer ‘Data Viper’ Hacked -
# 3  RT @dbongino: Liberalism is a cancer. Liberals...
# 4  RT @Melfox_14: Anyone know of good places to l...
#
#                                           tidy_tweet
# 0   gathering data every However only like employees
# 1  Florida reported highest number Covid cases Sa...
# 2            Breached Data Indexer Data Viper Hacked
# 3  Liberalism cancer Liberals hate free speech th...
# 4  Anyone know good places look remote work that ...

# %%
#write results to a csv
df.to_csv("tweets.csv", encoding='utf-8-sig', index=False)
