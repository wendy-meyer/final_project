# %%
import tweepy

consumer_key = '4VhQumsMUpEpV8zBNWXqqCKXF'
consumer_key_secret = 'IUBuBOBunYRupHkDEilKHezqZAwlCr0TXz6WjbG0TEaInI8Rdx'
access_token = '1280975848007512064-6IP319n9SpVPcCxMYPEsNIHh5LvCh7'
access_token_secret = 'CCKKnYjuxIysnxf6lijawbuRYTWCeUNVvthhxTc22V72Y'

# %%
twitter_auth = tweepy.OAuthHandler(consumer_key, consumer_key_secret)
api = tweepy.API(twitter_auth)

tweets = api.search("trump", count=10) # Search term goes here

print(tweets)
# Out:
# [Status(_api=<tweepy.api.API object at 0x0000020AB38F3AC8>, _json={'created_at': 'Fri Jul 10 01:16:02 +0000 2020', 'id': 1281396732144889856, 'id_str': '1281396732144889856', 'text': 'RT @TinaMorphis: The Secretary of Defense was briefed on Russian bounty on American soldiers — proving it isn’t the hoax Trump said it was…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'TinaMorphis', 'name': 'Tina Morphis #KHive #Humanist #ForthePeople', 'id': 942422990, 'id_str': '942422990', 'indices': [3, 15]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 358189714, 'id_str': '358189714', 'name': 'Sean', 'screen_name': 'tiltedgoof', 'location': '', 'description': "You can't promote principled anti-corruption action without pissing off corrupt people - George Kent //////\nSituational ethics aren't ethics at all", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 183, 'friends_count': 849, 'listed_count': 3, 'created_at': 'Fri Aug 19 14:38:58 +0000 2011', 'favourites_count': 39057, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 8811, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '022330', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1256735914719686656/h6vcvjc2_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1256735914719686656/h6vcvjc2_normal.jpg', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': '578BD9', 'profile_sidebar_fill_color': 'C0DFEC', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Fri Jul 10 01:12:30 +0000 2020', 'id': 1281395843539623936, 'id_str': '1281395843539623936', 'text': 'The Secretary of Defense was briefed on Russian bounty on American soldiers — proving it isn’t the hoax Trump said… https://t.co/1Uzd95fAMJ', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/1Uzd95fAMJ', 'expanded_url': 'https://twitter.com/i/web/status/1281395843539623936', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 942422990, 'id_str': '942422990', 'name': 'Tina Morphis #KHive #Humanist #ForthePeople', 'screen_name': 'TinaMorphis', 'location': '', 'description': 'BA Journalism/Public Relations, Do not go gentle into that good night  #Resistance #BlueWave #KHive', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 9911, 'friends_count': 7225, 'listed_count': 140, 'created_at': 'Sun Nov 11 23:01:59 +0000 2012', 'favourites_count': 258565, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 522872, 'lang': None, 'contributors_enabled': False, 'is_tran ...

# %%
import re
import pandas as pd


df = pd.DataFrame(columns=('tweet_text', 'user_location', 
                           'user_followers_count', 'user_friends_count',
                           'user_account_age', 'user_verified',
                           'user_favourites_count', 'user_tweets',
                           'tweet_retweeted', 'tweet_retweet_count', 'tweet_favorite_count'))

# Remove duplicates
df.sort_values("tweet_text", inplace = True) 
df.drop_duplicates(subset ="tweet_text", keep = False, inplace = True) 

for tweet in tweets:

    df = df.append({'tweet_text': re.sub(r'http\S+', '', tweet.text), # Removing any URL's in the tweet text here
                    'user_location': tweet.user.location,
                    'user_followers_count': tweet.user.followers_count, 
                    'user_friends_count': tweet.user.friends_count,
                    'user_account_age': tweet.user.created_at, 
                    'user_verified': tweet.user.verified,
                    'user_favourites_count': tweet.user.favourites_count,
                    'user_tweets': tweet.user.statuses_count,
                    'tweet_retweeted': tweet.retweeted,
                    'tweet_retweet_count': tweet.retweet_count,
                    'tweet_favorite_count': tweet.favorite_count},
                   ignore_index=True)

df.head()
# Out:
#                                           tweet_text          user_location  \
# 0  RT @TinaMorphis: The Secretary of Defense was ...
# 1         @endtimeslife @NightShiftNews Donald trump                England
# 2  RT @Salon: “I oversaw Pres. Obama’s financial ...  Tennessee, USA, Terra
# 3  RT @igorvolsky: The CEO of @GoyaFoods is at a ...
# 4  @GotMyACE Get used to it. Trump will be re-ele...
#
#   user_followers_count user_friends_count    user_account_age user_verified  \
# 0                  183                849 2011-08-19 14:38:58         False
# 1                 1288               2305 2009-03-22 00:36:18         False
# 2                  204                447 2014-03-24 07:06:18         False
# 3                  269                657 2010-03-20 13:37:09         False
# 4                  103                207 2011-11-12 19:27:14         False
#
#   user_favourites_count user_tweets tweet_retweeted tweet_retweet_count  \
# 0                 39057        8811           False                   3
# 1                   157        8711           False                   0
# 2                 26831       29820           False                   5
# 3                  2921        2773           False               10120
# 4                  1722        2942           False                   0
#
#   tweet_favorite_count
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
#write results to a csv
df.to_csv("tweets.csv", encoding='utf-8-sig', index=False)
